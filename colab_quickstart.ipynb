# %%
# 第一步：下载代码，进入目录并安装依赖
# !git clone https://github.com/your_username/tao-not-42-base.git
# %cd tao-not-42-base
# !pip install -r requirements.lock.txt

# %%
# 第二步：拉取最新代码并开始训练
# !git pull
# !python train.py
