# %%
# 第一步：下载代码，进入目录并安装依赖
# !git clone https://github.com/OopsYouDiedE/tao-not-42-base
# 请替换成对应版本的预编译包
# !pip install https://github.com/Dao-AILab/causal-conv1d/releases/download/v1.6.2.post1/causal_conv1d-1.6.2.post1%2Bcu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl -q

# !pip install https://github.com/state-spaces/mamba/releases/download/v2.3.2.post1/mamba_ssm-2.3.2.post1%2Bcu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl -q

# %cd tao-not-42-base

# %%
# 第二步：拉取最新代码，自动注入密钥并开始训练
import os
try:
    from google.colab import userdata
    # 在主进程拿到钥匙，挂在系统的环境变量上
    os.environ["WANDB_API_KEY"] = userdata.get('WANDB_API_KEY')
except Exception as e:
    print("Wandb 密钥自动获取失败，请确保已在侧边栏 Secrets 中设置 WANDB_API_KEY。")
# !git pull
# !pip install -r requirements.txt -q
print("ready")
# !python train.py
