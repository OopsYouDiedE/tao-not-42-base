# %%
# 第一步：下载代码，进入目录并安装依赖
# !git clone https://github.com/your_username/tao-not-42-base.git
# %cd tao-not-42-base
# !pip install -r requirements.txt

# %%
# 第二步：拉取最新代码，自动注入密钥并开始训练
import os
try:
    from google.colab import userdata
    os.environ["WANDB_API_KEY"] = userdata.get('WANDB_API_KEY')
except Exception as e:
    print("Wandb 密钥自动获取失败，请确保已在侧边栏 Secrets 中设置 WANDB_API_KEY。")

# !git pull
# !python train.py
